# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from tensorflow.keras.utils import to_categorical

# %%
(itrain, ltrain), (itest, ltest) = cifar10.load_data()

# %%
itrain = itrain / 255.0
itest = itest / 255.0
ltrain = to_categorical(ltrain)
ltest = to_categorical(ltest)

# %%
basem = VGG16(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

# %%
for layer in basem.layers:
    layer.trainable = False

# %%
semodel = Sequential()
semodel.add(basem)
semodel.add(Flatten())
semodel.add(Dense(256, activation='relu'))
semodel.add(Dense(10, activation='softmax'))

# %%
semodel.compile(optimizer='adam', loss='categorical_crossentropy',
metrics=['accuracy'])

# %%
semodel.fit(itrain, ltrain, epochs=10, batch_size=32, validation_data=(itest, ltest))
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 162s 103ms/step - accuracy: 0.5299 - loss: 1.3446 - val_accuracy: 0.5648 - val_loss: 1.2370
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 200s 102ms/step - accuracy: 0.5894 - loss: 1.1709 - val_accuracy: 0.5848 - val_loss: 1.1749
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 196s 98ms/step - accuracy: 0.6113 - loss: 1.1069 - val_accuracy: 0.5901 - val_loss: 1.1526
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 196s 94ms/step - accuracy: 0.6293 - loss: 1.0566 - val_accuracy: 0.6033 - val_loss: 1.1223
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 216s 102ms/step - accuracy: 0.6432 - loss: 1.0132 - val_accuracy: 0.6115 - val_loss: 1.1124
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 190s 95ms/step - accuracy: 0.6581 - loss: 0.9751 - val_accuracy: 0.6085 - val_loss: 1.1202
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 147s 94ms/step - accuracy: 0.6709 - loss: 0.9399 - val_accuracy: 0.6181 - val_loss: 1.1101
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 210s 100ms/step - accuracy: 0.6802 - loss: 0.9063 - val_accuracy: 0.6173 - val_loss: 1.1146
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 189s 92ms/step - accuracy: 0.6925 - loss: 0.8747 - val_accuracy: 0.6135 - val_loss: 1.1416
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 203s 92ms/step - accuracy: 0.7026 - loss: 0.8470 - val_accuracy: 0.6124 - val_loss: 1.1325

# %%
ltest, atest = semodel.evaluate(itest, ltest)
print("Test accuracy:", atest)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - accuracy: 0.6124 - loss: 1.1325
# Test accuracy: 0.6123999953269958
